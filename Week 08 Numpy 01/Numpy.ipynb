# %%
#Importing NumPy Library
import numpy as np

# %%
a = np.arange(10,100).reshape(3,3)
b = np.arange(100,109).reshape(3,3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 a = np.arange(100,100).reshape(30,30)
#       2 b = np.arange(100,190).reshape(30,30)
#
# ValueError: cannot reshape array of size 0 into shape (30,30)

# %%
np.matmul(a,b)
# Out:
# array([[ 4350,  4383,  4416,  4449,  4482,  4515,  4548,  4581,  4614,
#          4647,  4680,  4713,  4746,  4779,  4812,  4845,  4878,  4911,
#          4944,  4977,  5010,  5043,  5076,  5109,  5142,  5175,  5208,
#          5241,  5274,  5307],
#        [ 5520,  5562,  5604,  5646,  5688,  5730,  5772,  5814,  5856,
#          5898,  5940,  5982,  6024,  6066,  6108,  6150,  6192,  6234,
#          6276,  6318,  6360,  6402,  6444,  6486,  6528,  6570,  6612,
#          6654,  6696,  6738],
#        [ 6690,  6741,  6792,  6843,  6894,  6945,  6996,  7047,  7098,
#          7149,  7200,  7251,  7302,  7353,  7404,  7455,  7506,  7557,
#          7608,  7659,  7710,  7761,  7812,  7863,  7914,  7965,  8016,
#          8067,  8118,  8169],
#        [ 7860,  7920,  7980,  8040,  8100,  8160,  8220,  8280,  8340,
#          8400,  8460,  8520,  8580,  8640,  8700,  8760,  8820,  8880,
#          8940,  9000,  9060,  9120,  9180,  9240,  9300,  9360,  9420,
# ...
